# %%
Der Post von @dr_cintas
 kündigt die neue Integration von Google Colab in VS Code an, die es ermöglicht, direkt aus dem Editor auf eine kostenlose T4-GPU zuzugreifen, und demonstriert dies in einem 28-Sekunden-Video mit Pandas-Beispielen.
Die Einrichtung dauert etwa zwei Minuten: Installation der Colab-Erweiterung, Öffnen einer .ipynb-Datei und Auswahl eines Colab-Runtimes – ideal für Einsteiger in KI-Entwicklung ohne eigene Hardware.
Während der freie T4-Zugang Barrieren abbaut, gelten Einschränkungen wie 12-Stunden-Sitzungszeit, Inaktivitäts-Timeouts und Datenschutzrisiken durch Cloud-Nutzung, was lokale GPUs für sensible Projekte vorzuziehen macht.
